# %%
#pandas tutorial

# %%
import pandas as pd
import numpy as np

# %%
dict1={"name":["satyam","shivam","sundram"],
         "marks":[45,76,89],
        "city":["sdnagar","sknagar","sdnagar"]
      }

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#       name  marks     city
# 0   satyam     45  sdnagar
# 1   shivam     76  sknagar
# 2  sundram     89  sdnagar

# %%
df.to_csv("friends.csv")

# %%
iris=pd.read_csv("iris.csv")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width      class_type
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.info
# Out:
# <bound method DataFrame.info of      sepal_length  sepal_width  petal_length  petal_width      class_type
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
 iris.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width      class_type
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class_type
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df[marks]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-86507abdf8a0> in <module>
# ----> 1 df[marks]
#
# NameError: name 'marks' is not defined

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-ad11118bc8f3> in <module>
# ----> 1 df[0]
#
# ...

# %%
df[marks][0]=90
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-525b399e272e> in <module>
# ----> 1 df[marks][0]=90
#
# NameError: name 'marks' is not defined

# %%
df["marks"][0]=90
# Out:
# <ipython-input-16-e5b9e8566d94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["marks"][0]=90

# %%
df
# Out:
#       name  marks     city
# 0   satyam     90  sdnagar
# 1   shivam     76  sknagar
# 2  sundram     89  sdnagar

# %%
dict1["marks"][0]
# Out:
# 45

# %%
df["name"][1]="roli"
# Out:
# <ipython-input-20-d52aa3221360>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["name"][1]="roli"

# %%
df
# Out:
#       name  marks     city
# 0   satyam     90  sdnagar
# 1     roli     76  sknagar
# 2  sundram     89  sdnagar

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b959c06452a1> in <module>
# ----> 1 df.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
dtype(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4d7b74a763b4> in <module>
# ----> 1 dtype(df)
#
# NameError: name 'dtype' is not defined

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 3

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.271879
# 1     0.725902
# 2     0.794480
# 3     0.644115
# 4     0.301854
# 5     0.401788
# 6     0.372247
# 7     0.375001
# 8     0.270072
# 9     0.340940
# 10    0.215297
# 11    0.376736
# 12    0.536004
# 13    0.796994
# 14    0.407526
# 15    0.355922
# 16    0.006250
# 17    0.991295
# 18    0.587050
# 19    0.835066
# 20    0.026248
# 21    0.667242
# 22    0.660724
# 23    0.667353
# 24    0.074689
# 25    0.179064
# 26    0.590036
# 27    0.506433
# 28    0.051262
# 29    0.410809
# 30    0.051752
# 31    0.703454
# 32    0.170291
# 33    0.467558
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
np.dtype\
# Out:
#   File "<ipython-input-33-c852542c595c>", line 1
#     np.dtype\
#              ^
# SyntaxError: unexpected EOF while parsing

# %%
ser.dtypes
# Out:
# dtype('float64')

# %%
df.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-b959c06452a1> in <module>
# ----> 1 df.dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
new_df=pd.DataFrame(np.random.rand(50,5))

# %%
new_df
# Out:
#            0         1         2         3         4
# 0   0.127181  0.047807  0.779937  0.222708  0.435624
# 1   0.852131  0.948242  0.819527  0.493026  0.287602
# 2   0.114539  0.976093  0.381626  0.174549  0.519169
# 3   0.793748  0.118405  0.422303  0.842966  0.623022
# 4   0.791065  0.011876  0.900275  0.936488  0.941794
# 5   0.081191  0.162372  0.148840  0.587297  0.002316
# 6   0.037762  0.036271  0.309810  0.509368  0.671553
# 7   0.613343  0.174915  0.764061  0.074359  0.814581
# 8   0.364157  0.856104  0.841830  0.022450  0.756758
# 9   0.935113  0.295318  0.837651  0.321093  0.976568
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294
# 12  0.759149  0.910999  0.463852  0.262941  0.965408
# 13  0.223670  0.501795  0.317866  0.073386  0.393678
# 14  0.606519  0.661361  0.844176  0.321208  0.386989
# 15  0.659012  0.962240  0.005299  0.953808  0.371460
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# ...

# %%
new_df.head()
# Out:
#           0         1         2         3         4
# 0  0.127181  0.047807  0.779937  0.222708  0.435624
# 1  0.852131  0.948242  0.819527  0.493026  0.287602
# 2  0.114539  0.976093  0.381626  0.174549  0.519169
# 3  0.793748  0.118405  0.422303  0.842966  0.623022
# 4  0.791065  0.011876  0.900275  0.936488  0.941794

# %%
new_df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# class_type       object
# dtype: object

# %%
new_df[0][0]="shivam"

# %%
new_df
new_df.dtypes
# Out:
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
new_df.sum(axis=0)
# Out:
# 1    22.104261
# 2    25.891500
# 3    24.165823
# 4    26.767760
# dtype: float64

# %%
  ser=new_df.sum(axis=1)
# Out:
# 0     1.486077
# 1     2.548398
# 2     2.051436
# 3     2.006697
# 4     2.790433
# 5     0.900825
# 6     1.527001
# 7     1.827915
# 8     2.477142
# 9     2.430630
# 10    3.366235
# 11    2.437346
# 12    2.603199
# 13    1.286726
# 14    2.213734
# 15    2.292808
# 16    1.743614
# 17    1.971954
# 18    2.319892
# 19    2.606099
# 20    2.590124
# 21    1.774916
# 22    2.346980
# 23    1.319466
# 24    1.518774
# 25    1.089897
# 26    2.703009
# 27    1.035104
# 28    2.664766
# 29    2.404567
# 30    1.383262
# 31    1.235522
# 32    1.600448
# 33    2.130251
# 34    1.453582
# 35    2.183356
# 36    2.050349
# 37    1.490913
# 38    1.489531
# 39    2.352860
# 40    1.318014
# 41    1.143230
# 42    2.748548
# 43    1.480094
# 44    1.316387
# 45    1.531974
# 46    1.851345
# 47    2.557535
# 48    2.841737
# 49    2.434640
# dtype: float64

# %%
ser
# Out:
# 0     0.271879
# 1     0.725902
# 2     0.794480
# 3     0.644115
# 4     0.301854
# 5     0.401788
# 6     0.372247
# 7     0.375001
# 8     0.270072
# 9     0.340940
# 10    0.215297
# 11    0.376736
# 12    0.536004
# 13    0.796994
# 14    0.407526
# 15    0.355922
# 16    0.006250
# 17    0.991295
# 18    0.587050
# 19    0.835066
# 20    0.026248
# 21    0.667242
# 22    0.660724
# 23    0.667353
# 24    0.074689
# 25    0.179064
# 26    0.590036
# 27    0.506433
# 28    0.051262
# 29    0.410809
# 30    0.051752
# 31    0.703454
# 32    0.170291
# 33    0.467558
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser.sum(axis=0)
# Out:
# 14.833333294375244

# %%
new_df[0][0]=.23678
# Out:
# <ipython-input-52-f70ec6c95a37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[0][0]=.23678

# %%
 new_df
# Out:
#            0         1         2         3         4
# 0    0.23678  0.047807  0.779937  0.222708  0.435624
# 1   0.852131  0.948242  0.819527  0.493026  0.287602
# 2   0.114539  0.976093  0.381626  0.174549  0.519169
# 3   0.793748  0.118405  0.422303  0.842966  0.623022
# 4   0.791065  0.011876  0.900275  0.936488  0.941794
# 5   0.081191  0.162372  0.148840  0.587297  0.002316
# 6   0.037762  0.036271  0.309810  0.509368  0.671553
# 7   0.613343  0.174915  0.764061  0.074359  0.814581
# 8   0.364157  0.856104  0.841830  0.022450  0.756758
# 9   0.935113  0.295318  0.837651  0.321093  0.976568
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294
# 12  0.759149  0.910999  0.463852  0.262941  0.965408
# 13   0.22367  0.501795  0.317866  0.073386  0.393678
# 14  0.606519  0.661361  0.844176  0.321208  0.386989
# 15  0.659012  0.962240  0.005299  0.953808  0.371460
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# ...

# %%
  arr=new_df.to_numpy()

# %%
arr.shape
# Out:
# (50, 5)

# %%
arr.size
# Out:
# 250

# %%
new_df.shape
# Out:
# (50, 5)

# %%
new_df.size
# Out:
# 250

# %%
arr.reshpae(25,10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-02a605c94cb2> in <module>
# ----> 1 arr.reshpae(25,10)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'reshpae'

# %%
arr.reshape(25,10)
# Out:
# array([[0.23678, 0.04780745206329451, 0.7799372862037125,
#         0.22270845484201207, 0.43562379040184485, 0.8521308569042666,
#         0.9482417731427085, 0.819527431690999, 0.4930264606918445,
#         0.28760213272507973],
#        [0.11453895691701044, 0.9760928328959396, 0.3816258884164284,
#         0.17454889481378266, 0.5191687525066451, 0.7937481074419342,
#         0.11840538252017074, 0.4223029655784475, 0.8429663288158257,
#         0.6230219250546533],
#        [0.7910649255389641, 0.011876003750359132, 0.9002745313843327,
#         0.9364882258939424, 0.9417944109214084, 0.08119057358000814,
#         0.16237239711389817, 0.14883984983992138, 0.5872967379890094,
#         0.002315596333934855],
#        [0.037762372525274146, 0.0362707600959018, 0.3098095256566282,
#         0.5093681472022588, 0.6715528127370296, 0.6133430485338262,
#         0.17491469987134656, 0.7640606383438584, 0.07435867911861371,
#         0.8145808405599736],
# ...

# %%
new_df.index=np.linspace(49,0,50)

# %%
new_df.shape
# Out:
# (50, 5)

# %%
sq=np.arange(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-32324cbbea79> in <module>
# ----> 1 sq=np.arrange(50)
#
# ~\anaconda3\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     301                 return Tester
#     302
# --> 303             raise AttributeError("module {!r} has no attribute "
#     304                                  "{!r}".format(__name__, attr))
#     305
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
new_df
# Out:
#              0         1         2         3         4
# 49.0   0.23678  0.047807  0.779937  0.222708  0.435624
# 48.0  0.852131  0.948242  0.819527  0.493026  0.287602
# 47.0  0.114539  0.976093  0.381626  0.174549  0.519169
# 46.0  0.793748  0.118405  0.422303  0.842966  0.623022
# 45.0  0.791065  0.011876  0.900275  0.936488  0.941794
# 44.0  0.081191  0.162372  0.148840  0.587297  0.002316
# 43.0  0.037762  0.036271  0.309810  0.509368  0.671553
# 42.0  0.613343  0.174915  0.764061  0.074359  0.814581
# 41.0  0.364157  0.856104  0.841830  0.022450  0.756758
# 40.0  0.935113  0.295318  0.837651  0.321093  0.976568
# 39.0  0.578426  0.962471  0.730640  0.806501  0.866624
# 38.0  0.662007  0.369703  0.779933  0.700415  0.587294
# 37.0  0.759149  0.910999  0.463852  0.262941  0.965408
# 36.0   0.22367  0.501795  0.317866  0.073386  0.393678
# 35.0  0.606519  0.661361  0.844176  0.321208  0.386989
# 34.0  0.659012  0.962240  0.005299  0.953808  0.371460
# ...

# %%
new_df.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
new_df.columns=["first","second","third","fourth","fifth"]

# %%
new_df
# Out:
#              0         1         2         3         4
# 49.0   0.23678  0.047807  0.779937  0.222708  0.435624
# 48.0  0.852131  0.948242  0.819527  0.493026  0.287602
# 47.0  0.114539  0.976093  0.381626  0.174549  0.519169
# 46.0  0.793748  0.118405  0.422303  0.842966  0.623022
# 45.0  0.791065  0.011876  0.900275  0.936488  0.941794
# 44.0  0.081191  0.162372  0.148840  0.587297  0.002316
# 43.0  0.037762  0.036271  0.309810  0.509368  0.671553
# 42.0  0.613343  0.174915  0.764061  0.074359  0.814581
# 41.0  0.364157  0.856104  0.841830  0.022450  0.756758
# 40.0  0.935113  0.295318  0.837651  0.321093  0.976568
# 39.0  0.578426  0.962471  0.730640  0.806501  0.866624
# 38.0  0.662007  0.369703  0.779933  0.700415  0.587294
# 37.0  0.759149  0.910999  0.463852  0.262941  0.965408
# 36.0   0.22367  0.501795  0.317866  0.073386  0.393678
# 35.0  0.606519  0.661361  0.844176  0.321208  0.386989
# 34.0  0.659012  0.962240  0.005299  0.953808  0.371460
# ...

# %%
new_df.T
# Out:
#        49.0      48.0      47.0      46.0      45.0      44.0      43.0  \
# 0   0.23678  0.852131  0.114539  0.793748  0.791065  0.081191  0.037762
# 1  0.047807  0.948242  0.976093  0.118405  0.011876  0.162372  0.036271
# 2  0.779937  0.819527  0.381626  0.422303  0.900275   0.14884   0.30981
# 3  0.222708  0.493026  0.174549  0.842966  0.936488  0.587297  0.509368
# 4  0.435624  0.287602  0.519169  0.623022  0.941794  0.002316  0.671553
#
#        42.0      41.0      40.0  ...      9.0       8.0       7.0       6.0   \
# 0  0.613343  0.364157  0.935113  ...  0.669378  0.551785  0.271226  0.068979
# 1  0.174915  0.856104  0.295318  ...  0.053631  0.389345  0.734283  0.610008
# 2  0.764061   0.84183  0.837651  ...  0.338458   0.14843  0.858976   0.46308
# 3  0.074359   0.02245  0.321093  ...  0.588195  0.125815  0.810184  0.104083
# 4  0.814581  0.756758  0.976568  ...   0.33773   0.47964  0.345106  0.302923
#
#        5.0       4.0       3.0       2.0       1.0       0.0
# ...

# %%
new_df.sort_index(axis=1,ascending=False)
# Out:
#              4         3         2         1         0
# 49.0  0.435624  0.222708  0.779937  0.047807   0.23678
# 48.0  0.287602  0.493026  0.819527  0.948242  0.852131
# 47.0  0.519169  0.174549  0.381626  0.976093  0.114539
# 46.0  0.623022  0.842966  0.422303  0.118405  0.793748
# 45.0  0.941794  0.936488  0.900275  0.011876  0.791065
# 44.0  0.002316  0.587297  0.148840  0.162372  0.081191
# 43.0  0.671553  0.509368  0.309810  0.036271  0.037762
# 42.0  0.814581  0.074359  0.764061  0.174915  0.613343
# 41.0  0.756758  0.022450  0.841830  0.856104  0.364157
# 40.0  0.976568  0.321093  0.837651  0.295318  0.935113
# 39.0  0.866624  0.806501  0.730640  0.962471  0.578426
# 38.0  0.587294  0.700415  0.779933  0.369703  0.662007
# 37.0  0.965408  0.262941  0.463852  0.910999  0.759149
# 36.0  0.393678  0.073386  0.317866  0.501795   0.22367
# 35.0  0.386989  0.321208  0.844176  0.661361  0.606519
# 34.0  0.371460  0.953808  0.005299  0.962240  0.659012
# ...

# %%
new_df.columns=np.linspace(4,0,5)

# %%
new_df
# Out:
#          first    second     third    fourth     fifth
# 49.0   0.23678  0.047807  0.779937  0.222708  0.435624
# 48.0  0.852131  0.948242  0.819527  0.493026  0.287602
# 47.0  0.114539  0.976093  0.381626  0.174549  0.519169
# 46.0  0.793748  0.118405  0.422303  0.842966  0.623022
# 45.0  0.791065  0.011876  0.900275  0.936488  0.941794
# 44.0  0.081191  0.162372  0.148840  0.587297  0.002316
# 43.0  0.037762  0.036271  0.309810  0.509368  0.671553
# 42.0  0.613343  0.174915  0.764061  0.074359  0.814581
# 41.0  0.364157  0.856104  0.841830  0.022450  0.756758
# 40.0  0.935113  0.295318  0.837651  0.321093  0.976568
# 39.0  0.578426  0.962471  0.730640  0.806501  0.866624
# 38.0  0.662007  0.369703  0.779933  0.700415  0.587294
# 37.0  0.759149  0.910999  0.463852  0.262941  0.965408
# 36.0   0.22367  0.501795  0.317866  0.073386  0.393678
# 35.0  0.606519  0.661361  0.844176  0.321208  0.386989
# 34.0  0.659012  0.962240  0.005299  0.953808  0.371460
# ...

# %%
new_df1=new_df

# %%
new_df.index=np.arange(50)

# %%
new_df
# Out:
#        first    second     third    fourth     fifth
# 0    0.23678  0.047807  0.779937  0.222708  0.435624
# 1   0.852131  0.948242  0.819527  0.493026  0.287602
# 2   0.114539  0.976093  0.381626  0.174549  0.519169
# 3   0.793748  0.118405  0.422303  0.842966  0.623022
# 4   0.791065  0.011876  0.900275  0.936488  0.941794
# 5   0.081191  0.162372  0.148840  0.587297  0.002316
# 6   0.037762  0.036271  0.309810  0.509368  0.671553
# 7   0.613343  0.174915  0.764061  0.074359  0.814581
# 8   0.364157  0.856104  0.841830  0.022450  0.756758
# 9   0.935113  0.295318  0.837651  0.321093  0.976568
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294
# 12  0.759149  0.910999  0.463852  0.262941  0.965408
# 13   0.22367  0.501795  0.317866  0.073386  0.393678
# 14  0.606519  0.661361  0.844176  0.321208  0.386989
# 15  0.659012  0.962240  0.005299  0.953808  0.371460
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# ...

# %%
new_df["first"][0]=.456
# Out:
# <ipython-input-100-27fd5c877747>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["first"][0]=.456

# %%
new_df1
# Out:
#        first    second     third    fourth     fifth
# 0      0.456  0.047807  0.779937  0.222708  0.435624
# 1   0.852131  0.948242  0.819527  0.493026  0.287602
# 2   0.114539  0.976093  0.381626  0.174549  0.519169
# 3   0.793748  0.118405  0.422303  0.842966  0.623022
# 4   0.791065  0.011876  0.900275  0.936488  0.941794
# 5   0.081191  0.162372  0.148840  0.587297  0.002316
# 6   0.037762  0.036271  0.309810  0.509368  0.671553
# 7   0.613343  0.174915  0.764061  0.074359  0.814581
# 8   0.364157  0.856104  0.841830  0.022450  0.756758
# 9   0.935113  0.295318  0.837651  0.321093  0.976568
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294
# 12  0.759149  0.910999  0.463852  0.262941  0.965408
# 13   0.22367  0.501795  0.317866  0.073386  0.393678
# 14  0.606519  0.661361  0.844176  0.321208  0.386989
# 15  0.659012  0.962240  0.005299  0.953808  0.371460
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# ...

# %%
new_df.loc[0,0]=.89

# %%
new_df
# Out:
#        first    second     third    fourth     fifth     0
# 0      0.456  0.047807  0.779937  0.222708  0.435624  0.89
# 1   0.852131  0.948242  0.819527  0.493026  0.287602   NaN
# 2   0.114539  0.976093  0.381626  0.174549  0.519169   NaN
# 3   0.793748  0.118405  0.422303  0.842966  0.623022   NaN
# 4   0.791065  0.011876  0.900275  0.936488  0.941794   NaN
# 5   0.081191  0.162372  0.148840  0.587297  0.002316   NaN
# 6   0.037762  0.036271  0.309810  0.509368  0.671553   NaN
# 7   0.613343  0.174915  0.764061  0.074359  0.814581   NaN
# 8   0.364157  0.856104  0.841830  0.022450  0.756758   NaN
# 9   0.935113  0.295318  0.837651  0.321093  0.976568   NaN
# 10  0.578426  0.962471  0.730640  0.806501  0.866624   NaN
# 11  0.662007  0.369703  0.779933  0.700415  0.587294   NaN
# 12  0.759149  0.910999  0.463852  0.262941  0.965408   NaN
# 13   0.22367  0.501795  0.317866  0.073386  0.393678   NaN
# 14  0.606519  0.661361  0.844176  0.321208  0.386989   NaN
# ...

# %%
new_df=new_df.drop([0],axis=1)

# %%
new_df.dtypes
# Out:
# first      object
# second    float64
# third     float64
# fourth    float64
# fifth     float64
# dtype: object

# %%
new_df.loc[new_df.index,new_df.columns]
# Out:
#        first    second     third    fourth     fifth
# 0      0.456  0.047807  0.779937  0.222708  0.435624
# 1   0.852131  0.948242  0.819527  0.493026  0.287602
# 2   0.114539  0.976093  0.381626  0.174549  0.519169
# 3   0.793748  0.118405  0.422303  0.842966  0.623022
# 4   0.791065  0.011876  0.900275  0.936488  0.941794
# 5   0.081191  0.162372  0.148840  0.587297  0.002316
# 6   0.037762  0.036271  0.309810  0.509368  0.671553
# 7   0.613343  0.174915  0.764061  0.074359  0.814581
# 8   0.364157  0.856104  0.841830  0.022450  0.756758
# 9   0.935113  0.295318  0.837651  0.321093  0.976568
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294
# 12  0.759149  0.910999  0.463852  0.262941  0.965408
# 13   0.22367  0.501795  0.317866  0.073386  0.393678
# 14  0.606519  0.661361  0.844176  0.321208  0.386989
# 15  0.659012  0.962240  0.005299  0.953808  0.371460
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# ...

# %%
new_df.loc[(new_df["first"]<0.3)]
# Out:
#        first    second     third    fourth     fifth
# 2   0.114539  0.976093  0.381626  0.174549  0.519169
# 5   0.081191  0.162372  0.148840  0.587297  0.002316
# 6   0.037762  0.036271  0.309810  0.509368  0.671553
# 13   0.22367  0.501795  0.317866  0.073386  0.393678
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# 17  0.139147  0.860773  0.178682  0.764056  0.168443
# 20  0.178426  0.452581  0.883462  0.904569  0.349511
# 22  0.293961  0.388463  0.845721  0.944120  0.168676
# 27  0.290345  0.618530  0.014491  0.131589  0.270494
# 33  0.192772  0.210826  0.718188  0.607137  0.594100
# 34  0.159582  0.655792  0.187344  0.081300  0.529146
# 35  0.297842  0.597693  0.910701  0.179972  0.494991
# 42  0.271226  0.734283  0.858976  0.810184  0.345106
# 43  0.068979  0.610008  0.463080  0.104083  0.302923
# 44  0.151285  0.197927  0.341873  0.384263  0.392324
# 45  0.176322  0.018406  0.191139  0.506316  0.816113
# 46  0.288585  0.218231  0.352401  0.842459  0.438254
# ...

# %%
new_df["first"]
# Out:
# 0        0.456
# 1     0.852131
# 2     0.114539
# 3     0.793748
# 4     0.791065
# 5     0.081191
# 6     0.037762
# 7     0.613343
# 8     0.364157
# 9     0.935113
# 10    0.578426
# 11    0.662007
# 12    0.759149
# 13     0.22367
# 14    0.606519
# 15    0.659012
# 16    0.112098
# 17    0.139147
# 18       0.522
# 19    0.934181
# 20    0.178426
# 21    0.783381
# 22    0.293961
# 23    0.556294
# 24    0.773874
# 25    0.578766
# 26    0.578864
# 27    0.290345
# 28    0.475393
# 29     0.58809
# 30    0.765992
# 31    0.345534
# 32    0.370343
# 33    0.192772
# 34    0.159582
# 35    0.297842
# 36    0.892802
# 37    0.373198
# 38     0.68596
# 39    0.768013
# 40    0.669378
# 41    0.551785
# 42    0.271226
# 43    0.068979
# 44    0.151285
# 45    0.176322
# 46    0.288585
# 47    0.192617
# 48    0.240352
# 49    0.025576
# Name: first, dtype: object

# %%
new_df.sum(axis=0)
# Out:
# first     22.820797
# second    22.104261
# third       25.8915
# fourth    24.165823
# fifth      26.76776
# dtype: object

# %%
new_df.loc[np.arange(20),["first","second"]]
# Out:
#        first    second
# 0      0.456  0.047807
# 1   0.852131  0.948242
# 2   0.114539  0.976093
# 3   0.793748  0.118405
# 4   0.791065  0.011876
# 5   0.081191  0.162372
# 6   0.037762  0.036271
# 7   0.613343  0.174915
# 8   0.364157  0.856104
# 9   0.935113  0.295318
# 10  0.578426  0.962471
# 11  0.662007  0.369703
# 12  0.759149  0.910999
# 13   0.22367  0.501795
# 14  0.606519  0.661361
# 15  0.659012  0.962240
# 16  0.112098  0.375507
# 17  0.139147  0.860773
# 18     0.522  0.449735
# 19  0.934181  0.550278

# %%
new_df.loc[0,"first"]=0.9

# %%
new_df.loc[np.arange(10),new_df.columns]=0.7

# %%
new_df
# Out:
#        first    second     third    fourth     fifth
# 0        0.7  0.700000  0.700000  0.700000  0.700000
# 1        0.7  0.700000  0.700000  0.700000  0.700000
# 2        0.7  0.700000  0.700000  0.700000  0.700000
# 3        0.7  0.700000  0.700000  0.700000  0.700000
# 4        0.7  0.700000  0.700000  0.700000  0.700000
# 5        0.7  0.700000  0.700000  0.700000  0.700000
# 6        0.7  0.700000  0.700000  0.700000  0.700000
# 7        0.7  0.700000  0.700000  0.700000  0.700000
# 8        0.7  0.700000  0.700000  0.700000  0.700000
# 9        0.7  0.700000  0.700000  0.700000  0.700000
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294
# 12  0.759149  0.910999  0.463852  0.262941  0.965408
# 13   0.22367  0.501795  0.317866  0.073386  0.393678
# 14  0.606519  0.661361  0.844176  0.321208  0.386989
# 15  0.659012  0.962240  0.005299  0.953808  0.371460
# 16  0.112098  0.375507  0.482522  0.570709  0.314877
# ...

# %%
new_df.loc[[10,11]]
# Out:
#        first    second     third    fourth     fifth
# 10  0.578426  0.962471  0.730640  0.806501  0.866624
# 11  0.662007  0.369703  0.779933  0.700415  0.587294

# %%
list1=new_df.columns

# %%
list1
# Out:
# Index(['first', 'second', 'third', 'fourth', 'fifth'], dtype='object')

# %%
type(list1)
# Out:
# pandas.core.indexes.base.Index

# %%
 new_list=list(list1)

# %%
new_list.remove("fifth")

# %%
new_df.drop([5,6,7],axis=0, inplace=True)

# %%
new_df.append=pd.DataFrame(np.random.rand(50,5))

# %%
new_df.tail(8)
# Out:
#        first    second     third    fourth     fifth
# 42  0.271226  0.734283  0.858976  0.810184  0.345106
# 43  0.068979  0.610008  0.463080  0.104083  0.302923
# 44  0.151285  0.197927  0.341873  0.384263  0.392324
# 45  0.176322  0.018406  0.191139  0.506316  0.816113
# 46  0.288585  0.218231  0.352401  0.842459  0.438254
# 47  0.192617  0.394956  0.989504  0.576888  0.596188
# 48  0.240352  0.342196  0.742568  0.891656  0.865317
# 49  0.025576  0.906002  0.757124  0.692302  0.079213
